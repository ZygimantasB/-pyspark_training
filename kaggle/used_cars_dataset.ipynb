# %%
from pyspark.sql import SparkSession
import seaborn as sns
import matplotlib as plt
import altair as alt
import plotly.express as px

# %%
df_path = r"F:\Datasets\CSV datasets\vehicles.csv"

# %%
spark = SparkSession.builder.appName('Vehicles-Dataset').getOrCreate()

# %%
from pyspark.sql.types import StringType, StructType, IntegerType, FloatType, DoubleType, StructField, LongType, ShortType

# %% [markdown]
# # PySpark dtypes conversion cant throw error if conversion is incorrect

# %%
df = spark.read.csv(df_path, header=True, inferSchema=True)

# %%
df.count()
# Out:
# 441802

# %%
df.schema
# Out:
# StructType([StructField('id', StringType(), True), StructField('url', StringType(), True), StructField('region', StringType(), True), StructField('region_url', StringType(), True), StructField('price', StringType(), True), StructField('year', StringType(), True), StructField('manufacturer', StringType(), True), StructField('model', StringType(), True), StructField('condition', StringType(), True), StructField('cylinders', StringType(), True), StructField('fuel', StringType(), True), StructField('odometer', StringType(), True), StructField('title_status', StringType(), True), StructField('transmission', StringType(), True), StructField('VIN', StringType(), True), StructField('drive', StringType(), True), StructField('size', StringType(), True), StructField('type', StringType(), True), StructField('paint_color', StringType(), True), StructField('image_url', StringType(), True), StructField('description', StringType(), True), StructField('county', StringType(), True), StructField('state', StringType(), True), StructField('lat', StringType(), True), StructField('long', StringType(), True), StructField('posting_date', StringType(), True)])

# %%
print(df.schema)
# Out:
# StructType([StructField('id', StringType(), True), StructField('url', StringType(), True), StructField('region', StringType(), True), StructField('region_url', StringType(), True), StructField('price', StringType(), True), StructField('year', StringType(), True), StructField('manufacturer', StringType(), True), StructField('model', StringType(), True), StructField('condition', StringType(), True), StructField('cylinders', StringType(), True), StructField('fuel', StringType(), True), StructField('odometer', StringType(), True), StructField('title_status', StringType(), True), StructField('transmission', StringType(), True), StructField('VIN', StringType(), True), StructField('drive', StringType(), True), StructField('size', StringType(), True), StructField('type', StringType(), True), StructField('paint_color', StringType(), True), StructField('image_url', StringType(), True), StructField('description', StringType(), True), StructField('county', StringType(), True), StructField('state', StringType(), True), StructField('lat', StringType(), True), StructField('long', StringType(), True), StructField('posting_date', StringType(), True)])

# %%
df.show(5)
# Out:
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# |        id|                 url|              region|          region_url|price|year|manufacturer|model|condition|cylinders|fuel|odometer|title_status|transmission| VIN|drive|size|type|paint_color|image_url|description|county|state| lat|long|posting_date|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# |7222695916|https://prescott....|            prescott|https://prescott....| 6000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   az|NULL|NULL|        NULL|
# |7218891961|https://fayar.cra...|        fayetteville|https://fayar.cra...|11900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ar|NULL|NULL|        NULL|
# |7221797935|https://keys.crai...|        florida keys|https://keys.crai...|21000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   fl|NULL|NULL|        NULL|
# |7222270760|https://worcester...|worcester / centr...|https://worcester...| 1500|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ma|NULL|NULL|        NULL|
# |7210384030|https://greensbor...|          greensboro|https://greensbor...| 4900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   nc|NULL|NULL|        NULL|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, when, sum

# %%
df.select([
    sum(when(col(column).isNull(), 1).otherwise(0)).alias(column) for column in df.columns
]).show()
# Out:
# +---+----+------+----------+-----+----+------------+-----+---------+---------+-----+--------+------------+------------+------+------+------+------+-----------+---------+-----------+------+-----+-----+-----+------------+
# | id| url|region|region_url|price|year|manufacturer|model|condition|cylinders| fuel|odometer|title_status|transmission|   VIN| drive|  size|  type|paint_color|image_url|description|county|state|  lat| long|posting_date|
# +---+----+------+----------+-----+----+------------+-----+---------+---------+-----+--------+------------+------------+------+------+------+------+-----------+---------+-----------+------+-----+-----+-----+------------+
# |  0|9884|  6901|      6533| 6446|7890|       28937|17506|   187143|   190798|16344|   17801|       21618|       15932|174486|144178|319997|106892|     143839|    13732|      13733|382283|23077|25397|24715|       22477|
# +---+----+------+----------+-----+----+------------+-----+---------+---------+-----+--------+------------+------------+------+------+------+------+-----------+---------+-----------+------+-----+-----+-----+------------+

# %%
df.filter(df['id'].isNull()).count()
# Out:
# 0

# %%
df.filter(
    (col('price') > 6_000) &
    (col('region') != 'bellingham') &
    col('manufacturer').isNotNull()
).orderBy('price', ascending=False).show()
# Out:
# +----------+--------------------+--------------------+--------------------+--------+----+-------------+--------------------+---------+-----------+------+--------+------------+------------+-----------------+-----+---------+-----------+-----------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+
# |        id|                 url|              region|          region_url|   price|year| manufacturer|               model|condition|  cylinders|  fuel|odometer|title_status|transmission|              VIN|drive|     size|       type|paint_color|           image_url|         description| county|               state|                 lat|                long|        posting_date|
# +----------+--------------------+--------------------+--------------------+--------+----+-------------+--------------------+---------+-----------+------+--------+------------+------------+-----------------+-----+---------+-----------+-----------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+
# |7315961634|https://dothan.cr...|              dothan|https://dothan.cr...|99999999|1993|         ford|              ranger|     NULL|       NULL|   gas|   99999|       clean|   automatic|             NULL| NULL|     NULL|       NULL|       NULL|https://images.cr...|1993 Ford Ranger,...|   NULL|                  al|           31.053493|          -85.825968|2021-05-02T17:18:...|
# |7317067334|https://eauclaire...|          eau claire|https://eauclaire...|  999999|2006|         ford|               f-350|     NULL|8 cylinders|diesel|  204123|       clean|   automatic|             NULL| NULL|     NULL|       NULL|       NULL|https://images.cr...|New HPOP, new tur...|   NULL|                  wi|           45.263513|          -91.792354|2021-05-04T20:57:...|
# |7315498841|https://denver.cr...|              denver|https://denver.cr...|   99999|2015|         jeep|wrangler unlimite...|     NULL|8 cylinders|   gas|   15944|       clean|   automatic|1C4BJWFG1FL769739|  4wd|     NULL|        SUV|       NULL|https://images.cr...|Victory Motors of...|   NULL|                  co|           40.182151|         -105.102373|2021-05-01T14:51:...|
# |7315844696|https://palmsprin...|        palm springs|https://palmsprin...|   99999|1997|      ferrari|         f355 spider|excellent|8 cylinders|   gas|   22000|       clean|      manual|ZFFXR48A9V0108442| NULL|     NULL|convertible|       NULL|https://images.cr...|1997 Ferrari F355...|   NULL|                  ca|           33.743904|         -116.359028|2021-05-02T11:15:...|
# |7306693815|https://fortcolli...|fort collins / no...|https://fortcolli...|   99999|2015|         jeep|  wrangler unlimited|     NULL|8 cylinders|   gas|   15944|       clean|   automatic|1C4BJWFG1FL769739|  4wd|     NULL|        SUV|       NULL|https://images.cr...|Victory Motors of...|   NULL|                  co|           40.182151|         -105.102373|2021-04-14T09:49:...|
# |7317034296|https://denver.cr...|scottsbluff / pan...|https://scottsblu...|   99999|2020|         ford|f-150 shelby edition|excellent|8 cylinders|   gas|    9600|       clean|   automatic|1FTEW1E53LFA51587|  4wd|     NULL|     pickup|       blue|https://images.cr...|2020 Ford F-150 S...|   NULL|                  ne|            39.67851|         -104.932222|2021-05-04T18:19:...|
# |7314331344|https://palmsprin...|        palm springs|https://palmsprin...|   99999|1997|      ferrari|         f355 spider|excellent|8 cylinders|   gas|   22000|       clean|      manual|ZFFXR48A9V0108442| NULL|     NULL|convertible|       NULL|https://images.cr...|1997 Ferrari F355...|   NULL|                  ca|           33.743904|         -116.359028|2021-04-29T08:33:...|
# |7315009609|https://newyork.c...|       new york city|https://newyork.c...|   99999|2020|         ford|               f-150|     NULL|       NULL|   gas|    1404|       clean|   automatic|1FTEW1E52LFB87855|  4wd|     NULL|     pickup|      white|https://images.cr...|2020 Ford F-150 F...|   NULL|                  ny|           40.629452|          -74.128068|2021-04-30T16:40:...|
# |7311216665|https://newjersey...|        north jersey|https://newjersey...|   99999|2021|    chevrolet|            corvette|      new|8 cylinders|   gas|       1|       clean|   automatic|             NULL|  rwd|     NULL|       NULL|      black|https://images.cr...|2021 CHEVROLET CO...|   NULL|                  nj|             40.9564|            -74.1569|2021-04-23T00:41:...|
# |7316736746|https://austin.cr...|              austin|https://austin.cr...|   99995|2015|mercedes-benz|             s-class|     NULL|       NULL|   gas|   21107|       clean|   automatic|WDDXJ7KBXFA005640| NULL|     NULL|      coupe|       blue|https://images.cr...|Jaguar Land Rover...|   NULL|                  tx|           26.193466|          -98.145378|2021-05-04T10:30:...|
# |7316731003|https://mcallen.c...|  mcallen / edinburg|https://mcallen.c...|   99995|2015|mercedes-benz|             s-class|     NULL|       NULL|   gas|   21107|       clean|   automatic|WDDXJ7KBXFA005640| NULL|     NULL|      coupe|       blue|https://images.cr...|Jaguar Land Rover...|   NULL|                  tx|           26.193466|          -98.145378|2021-05-04T10:20:...|
# |7316736737|https://dallas.cr...| dallas / fort worth|https://dallas.cr...|   99995|2015|mercedes-benz|             s-class|     NULL|       NULL|   gas|   21107|       clean|   automatic|WDDXJ7KBXFA005640| NULL|     NULL|      coupe|       blue|https://images.cr...|Jaguar Land Rover...|   NULL|                  tx|           26.193466|          -98.145378|2021-05-04T10:30:...|
# |7317074911|https://seattle.c...|      seattle-tacoma|https://seattle.c...|   99991|2016|mercedes-benz|    s-class amg s 65|     NULL|       NULL|   gas|   34529|       clean|   automatic|WDDXJ7KB8GA015424| NULL|     NULL|      coupe|       NULL|https://images.cr...|APX Auto Brokers ...|   NULL|                  wa|           47.816633|         -122.318936|2021-05-04T19:24:...|
# |7309795516|https://neworlean...|         new orleans|https://neworlean...|   99991|2009|         audi|                  r8|     NULL|8 cylinders|   gas|   23229|       clean|      manual|WUAAU34279N001736|  4wd|     NULL|      coupe|       grey|https://images.cr...|"2009 Audi_ R8_ G...| appeal| and most importa...| NO ACCIDENTS  LO...| 305/25/20 REAR) ...| look no further!...|
# |7309795483|https://oklahomac...|       oklahoma city|https://oklahomac...|   99991|2009|         audi|                  r8|     NULL|8 cylinders|   gas|   23229|       clean|      manual|WUAAU34279N001736|  4wd|     NULL|      coupe|       grey|https://images.cr...|"2009 Audi_ R8_ G...| appeal| and most importa...| NO ACCIDENTS  LO...| 305/25/20 REAR) ...| look no further!...|
# |7316419515|https://honolulu....|              hawaii|https://honolulu....|   99990|2018|       nissan|            gt-r r35| like new|6 cylinders|   gas|    1234|       clean|   automatic|JN1AR5EF7JM710305|  4wd|full-size|      coupe|      white|https://images.cr...|LOCATED @ 1024 MA...|   NULL|                  hi|           21.344826|         -157.897735|2021-05-03T10:46:...|
# |7315467172|https://orlando.c...|             orlando|https://orlando.c...|    9999|2014|         ford|            explorer|     good|6 cylinders|   gas|   87000|     rebuilt|   automatic|1FM5K7B86EGB94233|  fwd|full-size|        SUV|      black|https://images.cr...|Hello, I am selli...|   NULL|                  fl|           28.697279|          -81.353269|2021-05-01T15:51:...|
# |7314063567|https://westslope...|       western slope|https://westslope...|    9999|2014|       nissan|              sentra|     good|4 cylinders|   gas|  111119|       clean|   automatic|             NULL|  fwd|  compact|      sedan|      white|https://images.cr...|2014 Nissan Sentr...|   NULL|                  co|           39.072738|         -108.517778|2021-04-28T15:50:...|
# |7315273499|https://miami.cra...|       south florida|https://miami.cra...|    9999|2010|         audi|     q5 premium plus| like new|       NULL|   gas|   80000|       clean|   automatic|             NULL|  4wd|  compact|        SUV|       grey|https://images.cr...|The car is in per...|   NULL|                  fl|             25.8156|            -80.1897|2021-05-01T10:16:...|
# |7314082258|https://boise.cra...|               boise|https://boise.cra...|    9999|2012|        mazda|              mazda3|     NULL|4 cylinders|   gas|   61857|       clean|   automatic|JM1BL1UG2C1555821|  fwd|     NULL|      sedan|       grey|https://images.cr...|2012 Mazda Mazda3...|   NULL|                  id|            44.06509|          -116.92924|2021-04-28T16:31:...|
# +----------+--------------------+--------------------+--------------------+--------+----+-------------+--------------------+---------+-----------+------+--------+------------+------------+-----------------+-----+---------+-----------+-----------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
df.withColumn(
    'price_above_6000', col('price') > 6_000
).show()
# Out:
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+----------------+
# |        id|                 url|              region|          region_url|price|year|manufacturer|model|condition|cylinders|fuel|odometer|title_status|transmission| VIN|drive|size|type|paint_color|image_url|description|county|state| lat|long|posting_date|price_above_6000|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+----------------+
# |7222695916|https://prescott....|            prescott|https://prescott....| 6000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   az|NULL|NULL|        NULL|           false|
# |7218891961|https://fayar.cra...|        fayetteville|https://fayar.cra...|11900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ar|NULL|NULL|        NULL|            true|
# |7221797935|https://keys.crai...|        florida keys|https://keys.crai...|21000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   fl|NULL|NULL|        NULL|            true|
# |7222270760|https://worcester...|worcester / centr...|https://worcester...| 1500|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ma|NULL|NULL|        NULL|           false|
# |7210384030|https://greensbor...|          greensboro|https://greensbor...| 4900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   nc|NULL|NULL|        NULL|           false|
# |7222379453|https://hudsonval...|       hudson valley|https://hudsonval...| 1600|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ny|NULL|NULL|        NULL|           false|
# |7221952215|https://hudsonval...|       hudson valley|https://hudsonval...| 1000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ny|NULL|NULL|        NULL|           false|
# |7220195662|https://hudsonval...|       hudson valley|https://hudsonval...|15995|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ny|NULL|NULL|        NULL|            true|
# |7209064557|https://medford.c...|     medford-ashland|https://medford.c...| 5000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   or|NULL|NULL|        NULL|           false|
# |7219485069|https://erie.crai...|                erie|https://erie.crai...| 3000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   pa|NULL|NULL|        NULL|           false|
# |7218893038|https://elpaso.cr...|             el paso|https://elpaso.cr...|    0|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   tx|NULL|NULL|        NULL|           false|
# |7218325704|https://elpaso.cr...|             el paso|https://elpaso.cr...|    0|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   tx|NULL|NULL|        NULL|           false|
# |7217788283|https://elpaso.cr...|             el paso|https://elpaso.cr...|    0|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   tx|NULL|NULL|        NULL|           false|
# |7217147606|https://elpaso.cr...|             el paso|https://elpaso.cr...|    0|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   tx|NULL|NULL|        NULL|           false|
# |7209027818|https://elpaso.cr...|             el paso|https://elpaso.cr...|    0|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   tx|NULL|NULL|        NULL|           false|
# |7223509794|https://bellingha...|          bellingham|https://bellingha...|13995|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   wa|NULL|NULL|        NULL|            true|
# |7222753076|https://bellingha...|          bellingham|https://bellingha...|24999|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   wa|NULL|NULL|        NULL|            true|
# |7222206015|https://bellingha...|          bellingham|https://bellingha...|21850|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   wa|NULL|NULL|        NULL|            true|
# |7220030122|https://bellingha...|          bellingham|https://bellingha...|26850|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   wa|NULL|NULL|        NULL|            true|
# |7218423006|https://bellingha...|          bellingham|https://bellingha...|11999|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   wa|NULL|NULL|        NULL|            true|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+----------------+
# only showing top 20 rows

# %%
df.groupBy('region').count().orderBy('count', ascending=False)
# Out:
# DataFrame[region: string, count: bigint]

# %%
print(df.select([
    sum(when(col(column).isNull(), 1).otherwise(0)).alias(column) for column in df.columns
]).show())
# Out:
# +---+----+------+----------+-----+----+------------+-----+---------+---------+-----+--------+------------+------------+------+------+------+------+-----------+---------+-----------+------+-----+-----+-----+------------+
# | id| url|region|region_url|price|year|manufacturer|model|condition|cylinders| fuel|odometer|title_status|transmission|   VIN| drive|  size|  type|paint_color|image_url|description|county|state|  lat| long|posting_date|
# +---+----+------+----------+-----+----+------------+-----+---------+---------+-----+--------+------------+------------+------+------+------+------+-----------+---------+-----------+------+-----+-----+-----+------------+
# |  0|9884|  6901|      6533| 6446|7890|       28937|17506|   187143|   190798|16344|   17801|       21618|       15932|174486|144178|319997|106892|     143839|    13732|      13733|382283|23077|25397|24715|       22477|
# +---+----+------+----------+-----+----+------------+-----+---------+---------+-----+--------+------------+------------+------+------+------+------+-----------+---------+-----------+------+-----+-----+-----+------------+
#
# None

# %%
df.show(5)
# Out:
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# |        id|                 url|              region|          region_url|price|year|manufacturer|model|condition|cylinders|fuel|odometer|title_status|transmission| VIN|drive|size|type|paint_color|image_url|description|county|state| lat|long|posting_date|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# |7222695916|https://prescott....|            prescott|https://prescott....| 6000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   az|NULL|NULL|        NULL|
# |7218891961|https://fayar.cra...|        fayetteville|https://fayar.cra...|11900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ar|NULL|NULL|        NULL|
# |7221797935|https://keys.crai...|        florida keys|https://keys.crai...|21000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   fl|NULL|NULL|        NULL|
# |7222270760|https://worcester...|worcester / centr...|https://worcester...| 1500|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ma|NULL|NULL|        NULL|
# |7210384030|https://greensbor...|          greensboro|https://greensbor...| 4900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   nc|NULL|NULL|        NULL|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# only showing top 5 rows

# %%
df.groupBy(col('year')).agg({'price': 'sum'}).orderBy('year', ascending=False).show()
# Out:
# +--------------------+-----------+
# |                year| sum(price)|
# +--------------------+-----------+
# |                  wa|       NULL|
# |                  dc|       NULL|
# |           47.656773|       NULL|
# |           45.382346|       NULL|
# |           40.624962|       NULL|
# |             34.1847|       NULL|
# |                2022|  3639818.0|
# |2021-05-04T20:41:...| -73.829146|
# |2021-05-04T20:33:...|-122.605132|
# |2021-05-04T20:31:...|-122.605132|
# |2021-05-04T20:29:...|-122.605132|
# |2021-05-04T20:21:...| -74.042702|
# |2021-05-04T19:56:...| -73.829146|
# |2021-05-04T18:56:...| -73.829146|
# |2021-05-04T18:56:...| -74.042702|
# |2021-05-04T18:46:...| -73.829146|
# |2021-05-04T18:31:...|  -97.13379|
# |2021-05-04T18:06:...| -122.57822|
# |2021-05-04T18:01:...| -106.38551|
# |2021-05-04T17:46:...| -73.829146|
# +--------------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import year

# %%
df.select(year('year')).collect()
# Out:
# [Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=None),
#  Row(year(year)=2014),
#  Row(year(year)=2010),
#  Row(year(year)=2020),
#  Row(year(year)=2017),
#  Row(year(year)=2013),
#  Row(year(year)=2012),
#  Row(year(year)=2016),
#  Row(year(year)=2019),
#  Row(year(year)=2016),
#  Row(year(year)=2011),
#  Row(year(year)=1992),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2014),
#  Row(year(year)=2016),
#  Row(year(year)=2014),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2011),
#  Row(year(year)=2018),
#  Row(year(year)=2016),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2017),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2004),
#  Row(year(year)=2016),
#  Row(year(year)=2016),
#  Row(year(year)=2015),
#  Row(year(year)=2012),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2001),
#  Row(year(year)=2019),
#  Row(year(year)=2013),
#  Row(year(year)=2014),
#  Row(year(year)=2016),
#  Row(year(year)=2012),
#  Row(year(year)=2014),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2020),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2020),
#  Row(year(year)=2012),
#  Row(year(year)=2019),
#  Row(year(year)=2015),
#  Row(year(year)=2018),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2004),
#  Row(year(year)=2016),
#  Row(year(year)=2019),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2015),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2006),
#  Row(year(year)=2004),
#  Row(year(year)=2016),
#  Row(year(year)=2013),
#  Row(year(year)=2018),
#  Row(year(year)=2015),
#  Row(year(year)=1968),
#  Row(year(year)=2017),
#  Row(year(year)=2019),
#  Row(year(year)=2013),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2019),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2003),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2015),
#  Row(year(year)=2016),
#  Row(year(year)=2020),
#  Row(year(year)=2018),
#  Row(year(year)=2008),
#  Row(year(year)=2007),
#  Row(year(year)=2018),
#  Row(year(year)=2005),
#  Row(year(year)=2019),
#  Row(year(year)=2019),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2020),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2018),
#  Row(year(year)=2018),
#  Row(year(year)=2016),
#  Row(year(year)=2020),
#  Row(year(year)=1966),
#  Row(year(year)=2006),
#  Row(year(year)=2019),
#  Row(year(year)=2012),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2012),
#  Row(year(year)=2018),
#  Row(year(year)=2020),
#  Row(year(year)=2013),
#  Row(year(year)=2018),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2015),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2015),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2018),
#  Row(year(year)=2018),
#  Row(year(year)=2020),
#  Row(year(year)=2012),
#  Row(year(year)=2011),
#  Row(year(year)=2001),
#  Row(year(year)=2005),
#  Row(year(year)=2010),
#  Row(year(year)=2011),
#  Row(year(year)=2008),
#  Row(year(year)=2007),
#  Row(year(year)=2014),
#  Row(year(year)=2011),
#  Row(year(year)=2007),
#  Row(year(year)=2011),
#  Row(year(year)=2009),
#  Row(year(year)=2008),
#  Row(year(year)=2009),
#  Row(year(year)=2006),
#  Row(year(year)=1998),
#  Row(year(year)=2002),
#  Row(year(year)=2008),
#  Row(year(year)=2020),
#  Row(year(year)=2017),
#  Row(year(year)=2007),
#  Row(year(year)=2015),
#  Row(year(year)=2008),
#  Row(year(year)=1998),
#  Row(year(year)=None),
#  Row(year(year)=2012),
#  Row(year(year)=2005),
#  Row(year(year)=1999),
#  Row(year(year)=2002),
#  Row(year(year)=2008),
#  Row(year(year)=2018),
#  Row(year(year)=2018),
#  Row(year(year)=2021),
#  Row(year(year)=2015),
#  Row(year(year)=2019),
#  Row(year(year)=2016),
#  Row(year(year)=2009),
#  Row(year(year)=1997),
#  Row(year(year)=1976),
#  Row(year(year)=2003),
#  Row(year(year)=1969),
#  Row(year(year)=2016),
#  Row(year(year)=2013),
#  Row(year(year)=2008),
#  Row(year(year)=2006),
#  Row(year(year)=2002),
#  Row(year(year)=2009),
#  Row(year(year)=2004),
#  Row(year(year)=2009),
#  Row(year(year)=1995),
#  Row(year(year)=2006),
#  Row(year(year)=2014),
#  Row(year(year)=2008),
#  Row(year(year)=2017),
#  Row(year(year)=2008),
#  Row(year(year)=2011),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=1978),
#  Row(year(year)=2005),
#  Row(year(year)=2012),
#  Row(year(year)=2018),
#  Row(year(year)=2011),
#  Row(year(year)=1999),
#  Row(year(year)=1954),
#  Row(year(year)=2017),
#  Row(year(year)=2011),
#  Row(year(year)=1979),
#  Row(year(year)=2003),
#  Row(year(year)=2019),
#  Row(year(year)=1970),
#  Row(year(year)=2009),
#  Row(year(year)=2014),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=1974),
#  Row(year(year)=1996),
#  Row(year(year)=2020),
#  Row(year(year)=2018),
#  Row(year(year)=2018),
#  Row(year(year)=2020),
#  Row(year(year)=2016),
#  Row(year(year)=2010),
#  Row(year(year)=2017),
#  Row(year(year)=2007),
#  Row(year(year)=2021),
#  Row(year(year)=2015),
#  Row(year(year)=2008),
#  Row(year(year)=2015),
#  Row(year(year)=2004),
#  Row(year(year)=2017),
#  Row(year(year)=2004),
#  Row(year(year)=2015),
#  Row(year(year)=2011),
#  Row(year(year)=1987),
#  Row(year(year)=2006),
#  Row(year(year)=2013),
#  Row(year(year)=2005),
#  Row(year(year)=2008),
#  Row(year(year)=2005),
#  Row(year(year)=2000),
#  Row(year(year)=1955),
#  Row(year(year)=2005),
#  Row(year(year)=1996),
#  Row(year(year)=2006),
#  Row(year(year)=2018),
#  Row(year(year)=2011),
#  Row(year(year)=2017),
#  Row(year(year)=2008),
#  Row(year(year)=2013),
#  Row(year(year)=1960),
#  Row(year(year)=2000),
#  Row(year(year)=2007),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2010),
#  Row(year(year)=2014),
#  Row(year(year)=2013),
#  Row(year(year)=2016),
#  Row(year(year)=2019),
#  Row(year(year)=2010),
#  Row(year(year)=2008),
#  Row(year(year)=2013),
#  Row(year(year)=2014),
#  Row(year(year)=2011),
#  Row(year(year)=2019),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2011),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=2018),
#  Row(year(year)=1991),
#  Row(year(year)=1999),
#  Row(year(year)=2006),
#  Row(year(year)=2003),
#  Row(year(year)=2005),
#  Row(year(year)=2017),
#  Row(year(year)=2011),
#  Row(year(year)=2009),
#  Row(year(year)=2011),
#  Row(year(year)=2001),
#  Row(year(year)=2010),
#  Row(year(year)=2006),
#  Row(year(year)=2010),
#  Row(year(year)=2014),
#  Row(year(year)=2020),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2019),
#  Row(year(year)=2006),
#  Row(year(year)=2010),
#  Row(year(year)=2015),
#  Row(year(year)=2013),
#  Row(year(year)=2008),
#  Row(year(year)=1997),
#  Row(year(year)=2007),
#  Row(year(year)=2009),
#  Row(year(year)=2012),
#  Row(year(year)=2013),
#  Row(year(year)=2012),
#  Row(year(year)=1998),
#  Row(year(year)=2011),
#  Row(year(year)=1972),
#  Row(year(year)=2019),
#  Row(year(year)=2009),
#  Row(year(year)=2012),
#  Row(year(year)=2005),
#  Row(year(year)=2005),
#  Row(year(year)=2016),
#  Row(year(year)=2021),
#  Row(year(year)=2001),
#  Row(year(year)=2017),
#  Row(year(year)=2012),
#  Row(year(year)=2007),
#  Row(year(year)=None),
#  Row(year(year)=2011),
#  Row(year(year)=2001),
#  Row(year(year)=2006),
#  Row(year(year)=2011),
#  Row(year(year)=2008),
#  Row(year(year)=2003),
#  Row(year(year)=2013),
#  Row(year(year)=2012),
#  Row(year(year)=2006),
#  Row(year(year)=2012),
#  Row(year(year)=2010),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2007),
#  Row(year(year)=2021),
#  Row(year(year)=2017),
#  Row(year(year)=2019),
#  Row(year(year)=2010),
#  Row(year(year)=2017),
#  Row(year(year)=2007),
#  Row(year(year)=2017),
#  Row(year(year)=2006),
#  Row(year(year)=2013),
#  Row(year(year)=2016),
#  Row(year(year)=2018),
#  Row(year(year)=2019),
#  Row(year(year)=2016),
#  Row(year(year)=2013),
#  Row(year(year)=2002),
#  Row(year(year)=2007),
#  Row(year(year)=2013),
#  Row(year(year)=2018),
#  Row(year(year)=2008),
#  Row(year(year)=2012),
#  Row(year(year)=1988),
#  Row(year(year)=2021),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2009),
#  Row(year(year)=2016),
#  Row(year(year)=2018),
#  Row(year(year)=2012),
#  Row(year(year)=2013),
#  Row(year(year)=2016),
#  Row(year(year)=2017),
#  Row(year(year)=2014),
#  Row(year(year)=1994),
#  Row(year(year)=2016),
#  Row(year(year)=2016),
#  Row(year(year)=2005),
#  Row(year(year)=1999),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2013),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2019),
#  Row(year(year)=2016),
#  Row(year(year)=2005),
#  Row(year(year)=2005),
#  Row(year(year)=2016),
#  Row(year(year)=2017),
#  Row(year(year)=2015),
#  Row(year(year)=2008),
#  Row(year(year)=2014),
#  Row(year(year)=2014),
#  Row(year(year)=2006),
#  Row(year(year)=2006),
#  Row(year(year)=2010),
#  Row(year(year)=2007),
#  Row(year(year)=2006),
#  Row(year(year)=2017),
#  Row(year(year)=2010),
#  Row(year(year)=2009),
#  Row(year(year)=2004),
#  Row(year(year)=2018),
#  Row(year(year)=2020),
#  Row(year(year)=1999),
#  Row(year(year)=2015),
#  Row(year(year)=2021),
#  Row(year(year)=2011),
#  Row(year(year)=2013),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=2005),
#  Row(year(year)=1988),
#  Row(year(year)=1988),
#  Row(year(year)=2018),
#  Row(year(year)=2014),
#  Row(year(year)=2019),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2021),
#  Row(year(year)=2008),
#  Row(year(year)=2015),
#  Row(year(year)=2015),
#  Row(year(year)=2021),
#  Row(year(year)=2010),
#  Row(year(year)=2019),
#  Row(year(year)=1999),
#  Row(year(year)=2017),
#  Row(year(year)=1968),
#  Row(year(year)=1969),
#  Row(year(year)=1929),
#  Row(year(year)=2003),
#  Row(year(year)=2011),
#  Row(year(year)=2002),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2021),
#  Row(year(year)=1998),
#  Row(year(year)=1999),
#  Row(year(year)=2004),
#  Row(year(year)=2007),
#  Row(year(year)=2012),
#  Row(year(year)=1969),
#  Row(year(year)=2019),
#  Row(year(year)=2012),
#  Row(year(year)=2018),
#  Row(year(year)=2016),
#  Row(year(year)=2007),
#  Row(year(year)=2006),
#  Row(year(year)=2017),
#  Row(year(year)=2006),
#  Row(year(year)=2000),
#  Row(year(year)=2011),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=2009),
#  Row(year(year)=2017),
#  Row(year(year)=2014),
#  Row(year(year)=2015),
#  Row(year(year)=2008),
#  Row(year(year)=2011),
#  Row(year(year)=2009),
#  Row(year(year)=2011),
#  Row(year(year)=2014),
#  Row(year(year)=2015),
#  Row(year(year)=2018),
#  Row(year(year)=2015),
#  Row(year(year)=2021),
#  Row(year(year)=2014),
#  Row(year(year)=2015),
#  Row(year(year)=2000),
#  Row(year(year)=2013),
#  Row(year(year)=2020),
#  Row(year(year)=2018),
#  Row(year(year)=2021),
#  Row(year(year)=2011),
#  Row(year(year)=2008),
#  Row(year(year)=2012),
#  Row(year(year)=2017),
#  Row(year(year)=2015),
#  Row(year(year)=2019),
#  Row(year(year)=2015),
#  Row(year(year)=2012),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2008),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2017),
#  Row(year(year)=2012),
#  Row(year(year)=2012),
#  Row(year(year)=2012),
#  Row(year(year)=2015),
#  Row(year(year)=2012),
#  Row(year(year)=2005),
#  Row(year(year)=2012),
#  Row(year(year)=2012),
#  Row(year(year)=2013),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2015),
#  Row(year(year)=2001),
#  Row(year(year)=2011),
#  Row(year(year)=2015),
#  Row(year(year)=1995),
#  Row(year(year)=2013),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2007),
#  Row(year(year)=2018),
#  Row(year(year)=2014),
#  Row(year(year)=2006),
#  Row(year(year)=2012),
#  Row(year(year)=2001),
#  Row(year(year)=2010),
#  Row(year(year)=2009),
#  Row(year(year)=2008),
#  Row(year(year)=2010),
#  Row(year(year)=2014),
#  Row(year(year)=2008),
#  Row(year(year)=2017),
#  Row(year(year)=2003),
#  Row(year(year)=1996),
#  Row(year(year)=2016),
#  Row(year(year)=2012),
#  Row(year(year)=2018),
#  Row(year(year)=2010),
#  Row(year(year)=2018),
#  Row(year(year)=2012),
#  Row(year(year)=2016),
#  Row(year(year)=2007),
#  Row(year(year)=2019),
#  Row(year(year)=2012),
#  Row(year(year)=2008),
#  Row(year(year)=2015),
#  Row(year(year)=2012),
#  Row(year(year)=2014),
#  Row(year(year)=2006),
#  Row(year(year)=2004),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2013),
#  Row(year(year)=2008),
#  Row(year(year)=2017),
#  Row(year(year)=2015),
#  Row(year(year)=2015),
#  Row(year(year)=2019),
#  Row(year(year)=2014),
#  Row(year(year)=2015),
#  Row(year(year)=2000),
#  Row(year(year)=2008),
#  Row(year(year)=2020),
#  Row(year(year)=None),
#  Row(year(year)=2021),
#  Row(year(year)=2008),
#  Row(year(year)=2016),
#  Row(year(year)=2020),
#  Row(year(year)=2016),
#  Row(year(year)=2014),
#  Row(year(year)=2014),
#  Row(year(year)=2019),
#  Row(year(year)=2002),
#  Row(year(year)=2002),
#  Row(year(year)=2003),
#  Row(year(year)=2012),
#  Row(year(year)=2002),
#  Row(year(year)=2015),
#  Row(year(year)=2013),
#  Row(year(year)=2015),
#  Row(year(year)=2011),
#  Row(year(year)=2019),
#  Row(year(year)=2019),
#  Row(year(year)=2013),
#  Row(year(year)=2004),
#  Row(year(year)=2008),
#  Row(year(year)=2006),
#  Row(year(year)=1997),
#  Row(year(year)=1997),
#  Row(year(year)=2008),
#  Row(year(year)=2005),
#  Row(year(year)=2020),
#  Row(year(year)=2010),
#  Row(year(year)=2013),
#  Row(year(year)=2016),
#  Row(year(year)=1999),
#  Row(year(year)=2001),
#  Row(year(year)=2016),
#  Row(year(year)=2017),
#  Row(year(year)=2008),
#  Row(year(year)=2014),
#  Row(year(year)=2018),
#  Row(year(year)=2011),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2007),
#  Row(year(year)=2012),
#  Row(year(year)=2019),
#  Row(year(year)=2014),
#  Row(year(year)=2003),
#  Row(year(year)=2014),
#  Row(year(year)=2010),
#  Row(year(year)=2019),
#  Row(year(year)=2002),
#  Row(year(year)=2008),
#  Row(year(year)=2013),
#  Row(year(year)=2017),
#  Row(year(year)=2021),
#  Row(year(year)=2016),
#  Row(year(year)=2012),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2018),
#  Row(year(year)=2019),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2018),
#  Row(year(year)=2011),
#  Row(year(year)=2017),
#  Row(year(year)=1979),
#  Row(year(year)=2002),
#  Row(year(year)=1996),
#  Row(year(year)=2011),
#  Row(year(year)=2008),
#  Row(year(year)=2010),
#  Row(year(year)=2013),
#  Row(year(year)=2011),
#  Row(year(year)=2013),
#  Row(year(year)=2005),
#  Row(year(year)=2006),
#  Row(year(year)=2008),
#  Row(year(year)=2008),
#  Row(year(year)=2012),
#  Row(year(year)=2007),
#  Row(year(year)=2005),
#  Row(year(year)=2008),
#  Row(year(year)=2008),
#  Row(year(year)=2005),
#  Row(year(year)=2017),
#  Row(year(year)=2014),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2014),
#  Row(year(year)=2009),
#  Row(year(year)=2007),
#  Row(year(year)=2016),
#  Row(year(year)=1984),
#  Row(year(year)=2013),
#  Row(year(year)=2019),
#  Row(year(year)=2019),
#  Row(year(year)=2017),
#  Row(year(year)=2019),
#  Row(year(year)=2017),
#  Row(year(year)=None),
#  Row(year(year)=2009),
#  Row(year(year)=2006),
#  Row(year(year)=2013),
#  Row(year(year)=2011),
#  Row(year(year)=2005),
#  Row(year(year)=2010),
#  Row(year(year)=2009),
#  Row(year(year)=1997),
#  Row(year(year)=2010),
#  Row(year(year)=2006),
#  Row(year(year)=2009),
#  Row(year(year)=2006),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2006),
#  Row(year(year)=2013),
#  Row(year(year)=2001),
#  Row(year(year)=2011),
#  Row(year(year)=2020),
#  Row(year(year)=2007),
#  Row(year(year)=2012),
#  Row(year(year)=2006),
#  Row(year(year)=2014),
#  Row(year(year)=2016),
#  Row(year(year)=2013),
#  Row(year(year)=2011),
#  Row(year(year)=2006),
#  Row(year(year)=2005),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=None),
#  Row(year(year)=2016),
#  Row(year(year)=2017),
#  Row(year(year)=2008),
#  Row(year(year)=2003),
#  Row(year(year)=1999),
#  Row(year(year)=2015),
#  Row(year(year)=2015),
#  Row(year(year)=2019),
#  Row(year(year)=2014),
#  Row(year(year)=2006),
#  Row(year(year)=2003),
#  Row(year(year)=2014),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2014),
#  Row(year(year)=2011),
#  Row(year(year)=2011),
#  Row(year(year)=2021),
#  Row(year(year)=1991),
#  Row(year(year)=2018),
#  Row(year(year)=None),
#  Row(year(year)=1984),
#  Row(year(year)=2001),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2013),
#  Row(year(year)=2019),
#  Row(year(year)=2019),
#  Row(year(year)=2019),
#  Row(year(year)=2014),
#  Row(year(year)=2014),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2001),
#  Row(year(year)=1987),
#  Row(year(year)=2020),
#  Row(year(year)=2016),
#  Row(year(year)=2003),
#  Row(year(year)=2012),
#  Row(year(year)=2000),
#  Row(year(year)=2006),
#  Row(year(year)=2006),
#  Row(year(year)=2005),
#  Row(year(year)=2010),
#  Row(year(year)=2008),
#  Row(year(year)=2008),
#  Row(year(year)=2011),
#  Row(year(year)=2011),
#  Row(year(year)=2013),
#  Row(year(year)=2015),
#  Row(year(year)=2013),
#  Row(year(year)=2016),
#  Row(year(year)=2004),
#  Row(year(year)=2015),
#  Row(year(year)=2007),
#  Row(year(year)=2016),
#  Row(year(year)=2012),
#  Row(year(year)=2007),
#  Row(year(year)=2006),
#  Row(year(year)=2017),
#  Row(year(year)=2013),
#  Row(year(year)=2007),
#  Row(year(year)=2012),
#  Row(year(year)=2012),
#  Row(year(year)=2014),
#  Row(year(year)=2007),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2010),
#  Row(year(year)=2008),
#  Row(year(year)=2015),
#  Row(year(year)=2016),
#  Row(year(year)=2007),
#  Row(year(year)=2016),
#  Row(year(year)=2005),
#  Row(year(year)=2006),
#  Row(year(year)=2016),
#  Row(year(year)=2008),
#  Row(year(year)=2016),
#  Row(year(year)=2014),
#  Row(year(year)=2010),
#  Row(year(year)=2017),
#  Row(year(year)=2009),
#  Row(year(year)=2007),
#  Row(year(year)=2006),
#  Row(year(year)=2004),
#  Row(year(year)=2011),
#  Row(year(year)=2012),
#  Row(year(year)=2008),
#  Row(year(year)=2007),
#  Row(year(year)=2005),
#  Row(year(year)=2015),
#  Row(year(year)=2015),
#  Row(year(year)=1998),
#  Row(year(year)=2008),
#  Row(year(year)=2015),
#  Row(year(year)=2017),
#  Row(year(year)=2016),
#  Row(year(year)=2006),
#  Row(year(year)=2004),
#  Row(year(year)=2008),
#  Row(year(year)=2012),
#  Row(year(year)=2008),
#  Row(year(year)=2011),
#  Row(year(year)=2016),
#  Row(year(year)=2016),
#  Row(year(year)=2012),
#  Row(year(year)=2012),
#  Row(year(year)=2016),
#  Row(year(year)=2015),
#  Row(year(year)=2008),
#  Row(year(year)=2018),
#  Row(year(year)=2014),
#  Row(year(year)=2015),
#  Row(year(year)=2008),
#  Row(year(year)=2010),
#  Row(year(year)=2008),
#  Row(year(year)=2014),
#  Row(year(year)=2016),
#  Row(year(year)=2014),
#  Row(year(year)=2011),
#  Row(year(year)=2015),
#  Row(year(year)=2012),
#  Row(year(year)=2007),
#  Row(year(year)=2006),
#  Row(year(year)=2015),
#  Row(year(year)=2004),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=2009),
#  Row(year(year)=2006),
#  Row(year(year)=2017),
#  Row(year(year)=2011),
#  Row(year(year)=2007),
#  Row(year(year)=2010),
#  Row(year(year)=2006),
#  Row(year(year)=2016),
#  Row(year(year)=2012),
#  Row(year(year)=2016),
#  Row(year(year)=2004),
#  Row(year(year)=2016),
#  Row(year(year)=2016),
#  Row(year(year)=2008),
#  Row(year(year)=2008),
#  Row(year(year)=2012),
#  Row(year(year)=2011),
#  Row(year(year)=2017),
#  Row(year(year)=2006),
#  Row(year(year)=2015),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=2019),
#  Row(year(year)=None),
#  Row(year(year)=1994),
#  Row(year(year)=2020),
#  Row(year(year)=2007),
#  Row(year(year)=2011),
#  Row(year(year)=2021),
#  Row(year(year)=2009),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2017),
#  Row(year(year)=2015),
#  Row(year(year)=2018),
#  Row(year(year)=2007),
#  Row(year(year)=2017),
#  Row(year(year)=2015),
#  Row(year(year)=2019),
#  Row(year(year)=2003),
#  Row(year(year)=2018),
#  Row(year(year)=2008),
#  Row(year(year)=2015),
#  Row(year(year)=2014),
#  Row(year(year)=2015),
#  Row(year(year)=1994),
#  Row(year(year)=2005),
#  Row(year(year)=1995),
#  Row(year(year)=2003),
#  Row(year(year)=2006),
#  Row(year(year)=2006),
#  Row(year(year)=2008),
#  Row(year(year)=2014),
#  Row(year(year)=2013),
#  Row(year(year)=2013),
#  Row(year(year)=2013),
#  Row(year(year)=2021),
#  Row(year(year)=2020),
#  Row(year(year)=2010),
#  Row(year(year)=2007),
#  Row(year(year)=2017),
#  Row(year(year)=2004),
#  Row(year(year)=2004),
#  Row(year(year)=2006),
#  Row(year(year)=2011),
#  Row(year(year)=2011),
#  Row(year(year)=2012),
#  Row(year(year)=2017),
#  Row(year(year)=2019),
#  Row(year(year)=1986),
#  Row(year(year)=2017),
#  Row(year(year)=1989),
#  Row(year(year)=2016),
#  Row(year(year)=2016),
#  Row(year(year)=1998),
#  Row(year(year)=2006),
#  Row(year(year)=2019),
#  Row(year(year)=2013),
#  Row(year(year)=2018),
#  Row(year(year)=None),
#  Row(year(year)=2017),
#  Row(year(year)=2019),
#  Row(year(year)=2020),
#  Row(year(year)=2017),
#  Row(year(year)=2017),
#  Row(year(year)=2006),
#  Row(year(year)=2004),
#  Row(year(year)=2014),
#  Row(year(year)=2002),
#  Row(year(year)=2010),
#  Row(year(year)=2015),
#  Row(year(year)=2005),
#  Row(year(year)=1999),
#  Row(year(year)=2014),
#  Row(year(year)=2015),
#  Row(year(year)=2007),
#  Row(year(year)=2006),
#  Row(year(year)=2010),
#  Row(year(year)=2009),
#  Row(year(year)=2013),
#  Row(year(year)=2006),
#  Row(year(year)=2008),
#  Row(year(year)=2008),
#  Row(year(year)=2005),
#  Row(year(year)=2006),
#  Row(year(year)=2006),
#  Row(year(year)=2012),
#  Row(year(year)=2012),
#  Row(year(year)=2008),
#  Row(year(year)=2001),
#  Row(year(year)=2009),
#  Row(year(year)=2017),
#  Row(year(year)=2013),
#  Row(year(year)=2011),
#  Row(year(year)=2008),
#  Row(year(year)=2016),
#  Row(year(year)=2014),
#  Row(year(year)=2002),
#  Row(year(year)=2018),
#  Row(year(year)=2013),
#  Row(year(year)=2000),
#  Row(year(year)=2014),
#  Row(year(year)=2016),
#  Row(year(year)=2019),
#  Row(year(year)=None),
#  Row(year(year)=2019),
#  Row(year(year)=2004),
#  Row(year(year)=2020),
#  Row(year(year)=2020),
#  Row(year(year)=2019),
#  Row(year(year)=2016),
#  Row(year(year)=2018),
#  Row(year(year)=2017),
#  Row(year(year)=2014),
#  Row(year(year)=2002),
#  Row(year(year)=2002),
#  Row(year(year)=2008),
#  Row(year(year)=2010),
#  Row(year(year)=2005),
#  Row(year(year)=2012),
#  Row(year(year)=2011),
#  Row(year(year)=2017),
#  Row(year(year)=2013),
#  Row(year(year)=2008),
#  Row(year(year)=2004),
#  Row(year(year)=2011),
#  Row(year(year)=2015),
#  Row(year(year)=2019),
#  Row(year(year)=2013),
#  Row(year(year)=2008),
#  Row(year(year)=2005),
#  Row(year(year)=2005),
#  Row(year(year)=1973),
#  Row(year(year)=2020),
#  Row(year(year)=2018),
#  Row(year(year)=2000),
#  Row(year(year)=2021),
#  Row(year(year)=2011),
#  Row(year(year)=None),
#  Row(year(year)=2018),
#  ...]

# %%
df.show(5)
# Out:
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# |        id|                 url|              region|          region_url|price|year|manufacturer|model|condition|cylinders|fuel|odometer|title_status|transmission| VIN|drive|size|type|paint_color|image_url|description|county|state| lat|long|posting_date|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# |7222695916|https://prescott....|            prescott|https://prescott....| 6000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   az|NULL|NULL|        NULL|
# |7218891961|https://fayar.cra...|        fayetteville|https://fayar.cra...|11900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ar|NULL|NULL|        NULL|
# |7221797935|https://keys.crai...|        florida keys|https://keys.crai...|21000|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   fl|NULL|NULL|        NULL|
# |7222270760|https://worcester...|worcester / centr...|https://worcester...| 1500|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   ma|NULL|NULL|        NULL|
# |7210384030|https://greensbor...|          greensboro|https://greensbor...| 4900|NULL|        NULL| NULL|     NULL|     NULL|NULL|    NULL|        NULL|        NULL|NULL| NULL|NULL|NULL|       NULL|     NULL|       NULL|  NULL|   nc|NULL|NULL|        NULL|
# +----------+--------------------+--------------------+--------------------+-----+----+------------+-----+---------+---------+----+--------+------------+------------+----+-----+----+----+-----------+---------+-----------+------+-----+----+----+------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- region_url: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- manufacturer: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- condition: string (nullable = true)
#  |-- cylinders: string (nullable = true)
#  |-- fuel: string (nullable = true)
#  |-- odometer: string (nullable = true)
#  |-- title_status: string (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- VIN: string (nullable = true)
#  |-- drive: string (nullable = true)
#  |-- size: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- paint_color: string (nullable = true)
#  |-- image_url: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- county: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- lat: string (nullable = true)
#  |-- long: string (nullable = true)
#  |-- posting_date: string (nullable = true)

# %%
df.count()
# Out:
# 441802

# %%
df.select(['price', 'year', 'manufacturer']).show(5)
# Out:
# +-----+----+------------+
# |price|year|manufacturer|
# +-----+----+------------+
# | 6000|NULL|        NULL|
# |11900|NULL|        NULL|
# |21000|NULL|        NULL|
# | 1500|NULL|        NULL|
# | 4900|NULL|        NULL|
# +-----+----+------------+
# only showing top 5 rows

# %%
df.select(col('year'), col('price'), col('manufacturer')).show(5)
# Out:
# +----+-----+------------+
# |year|price|manufacturer|
# +----+-----+------------+
# |NULL| 6000|        NULL|
# |NULL|11900|        NULL|
# |NULL|21000|        NULL|
# |NULL| 1500|        NULL|
# |NULL| 4900|        NULL|
# +----+-----+------------+
# only showing top 5 rows

# %%
from pyspark.sql.types import (StringType, StructType, IntegerType, FloatType, DoubleType, StructField, LongType,
                               ShortType, YearMonthIntervalType, DateType, CharType)

# %%
year_not_null = df.filter(col('year').isNotNull())

year_not_null.withColumns({
    'id': col('id').cast(LongType()),
    'url': col('url').cast(StringType()),
    'region': col('region').cast(StringType()),
    'price': col('price').cast(IntegerType()),
    'year': col('year').cast(ShortType()),
    'manufacturer': col('manufacturer').cast(StringType()),
}).show(5, truncate=False)
# Out:
# +----------+------------------------------------------------------------------------------------------+------+-----------------------------+-----+----+------------+------------------------+---------+-----------+----+--------+------------+------------+-----------------+-----+---------+------+-----------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |id        |url                                                                                       |region|region_url                   |price|year|manufacturer|model                   |condition|cylinders  |fuel|odometer|title_status|transmission|VIN              |drive|size     |type  |paint_color|image_url                                                          |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +----------+------------------------------------------------------------------------------------------+------+-----------------------------+-----+----+------------+------------------------+---------+-----------+----+--------+------------+------------+-----------------+-----+---------+------+-----------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |7316814884|https://auburn.craigslist.org/ctd/d/auburn-university-2014-gmc-sierra-1500/7316814884.html|auburn|https://auburn.craigslist.org|33590|2014|gmc         |sierra 1500 crew cab slt|good     |8 cylinders|gas |57923   |clean       |other       |3GTP1VEC4EG551563|NULL |NULL     |pickup|white      |https://images.craigslist.org/00R0R_lwWjXSEWNa7z_0x20oM_600x450.jpg|Carvana is the safer way to buy a car During these uncertain times, Carvana is dedicated to ensuring safety for all of our customers. In addition to our 100% online shopping and selling experience that allows all customers to buy and trade their cars without ever leaving the safety of their house, we’re providing touchless delivery that make all aspects of our process even safer. Now, you can get the car you want, and trade in your old one, while avoiding person-to-person contact with our friendly advocates. There are some things that can’t be put off. And if buying a car is one of them, know that we’re doing everything we can to keep you keep moving while continuing to put your health safety, and happiness first. Vehicle Stock# 2000909557📱 Want to instantly check this car’s availability? Call us at  334-758-9176Just text that stock number to 855-976-4304 or head to http://www.carvanaauto.com/7171237-74502 and plug it into the search bar!Get PRE-QUALIFIED for your auto loan in 2 minutes - no hit to your credit:http://finance.carvanaauto.com/7171237-74502Looking for more cars like this one? We have 63 GMC Sierra 1500 Crew Cab in stock for as low as $23990!Why buy with Carvana? We have one standard: the highest. Take a look at just some of the qualifications all of our cars must meet before we list them.150-POINT INSPECTION: We put each vehicle through a 150-point inspection so that you can be 100% confident in its quality and safety. See everything that goes into our inspections at:http://www.carvanaauto.com/7171237-74502NO REPORTED ACCIDENTS: We do not sell cars that have been in a reported accident or have a frame or structural damage.7 DAY TEST OWN MONEY BACK GUARANTEE: Every Carvana car comes with a 7-day money-back guarantee. Why? It takes more than 15-minutes to make a decision on your next car. Learn more about test owning at http://about.carvanaauto.comFLEXIBLE FINANCING, TRADE INS WELCOME: We’re all about real-time financing without the middle man. Need financing? Pick a combination of down and monthly payments that work for you. Have a trade-in? We’ll give you a value in 2 minutes. Check out everything about our financing at:http://finance.carvanaauto.com/7171237-74502COST SAVINGS: Carvana's business model has fewer expenses and no bloated fees compared to your local dealership. See how much we can save you at http://about.carvanaauto.comPREMIUM DETAIL: We go the extra mile so that your car is looking as good as new. There are a lot of specifics that we won’t list here (we wash, clean, buff, paint, polish, wax, seal), but trust us that when your car arrives, it’s going to look sweet.Vehicle Info for Stock# 2000909557Trim: SLT Pickup 4D 5 3/4 ft pickupMileage: 57k milesExterior Color: WhiteInterior Color: Lt. BrownEngine: EcoTec3 5.3L Flex Fuel V8 355hp 383ft. lbs.Drive: Two Wheel DriveTransmission: VIN: 3GTP1VEC4EG551563Dealer Disclosure: Price excludes tax, title, and registration (which we handle for you).Disclaimer: You agree that by providing your phone number, Carvana, or Carvana’s authorized representatives*, may call and/or send text messages (including by using equipment to automatically dial telephone numbers) about your interest in a purchase, for marketing/sales purposes, or for any other servicing or informational purpose related to your account. You do not have to consent to receiving calls or texts to purchase from Carvana. While every reasonable effort is made to ensure the accuracy of the information for this GMC Sierra 1500 Crew Cab, we are not responsible for any errors or omissions contained in this ad. Please verify any information i ...
# |7316814758|https://auburn.craigslist.org/ctd/d/auburn-university-2010-chevy-chevrolet/7316814758.html|auburn|https://auburn.craigslist.org|22590|2010|chevrolet   |silverado 1500          |good     |8 cylinders|gas |71229   |clean       |other       |1GCSCSE06AZ123805|NULL |NULL     |pickup|blue       |https://images.craigslist.org/00R0R_lwWjXSEWNa7z_0x20oM_600x450.jpg|Carvana is the safer way to buy a car During these uncertain times, Carvana is dedicated to ensuring safety for all of our customers. In addition to our 100% online shopping and selling experience that allows all customers to buy and trade their cars without ever leaving the safety of their house, we’re providing touchless delivery that make all aspects of our process even safer. Now, you can get the car you want, and trade in your old one, while avoiding person-to-person contact with our friendly advocates. There are some things that can’t be put off. And if buying a car is one of them, know that we’re doing everything we can to keep you keep moving while continuing to put your health safety, and happiness first. Vehicle Stock# 2000977114📱 Want to instantly check this car’s availability? Call us at  334-758-9176Just text that stock number to 855-976-4304 or head to http://www.carvanaauto.com/7163375-74502 and plug it into the search bar!Get PRE-QUALIFIED for your auto loan in 2 minutes - no hit to your credit:http://finance.carvanaauto.com/7163375-74502Looking for more cars like this one? We have 10 Chevrolet Silverado 1500 Extended Cab in stock for as low as $20990!Why buy with Carvana? We have one standard: the highest. Take a look at just some of the qualifications all of our cars must meet before we list them.150-POINT INSPECTION: We put each vehicle through a 150-point inspection so that you can be 100% confident in its quality and safety. See everything that goes into our inspections at:http://www.carvanaauto.com/7163375-74502NO REPORTED ACCIDENTS: We do not sell cars that have been in a reported accident or have a frame or structural damage.7 DAY TEST OWN MONEY BACK GUARANTEE: Every Carvana car comes with a 7-day money-back guarantee. Why? It takes more than 15-minutes to make a decision on your next car. Learn more about test owning at http://about.carvanaauto.comFLEXIBLE FINANCING, TRADE INS WELCOME: We’re all about real-time financing without the middle man. Need financing? Pick a combination of down and monthly payments that work for you. Have a trade-in? We’ll give you a value in 2 minutes. Check out everything about our financing at:http://finance.carvanaauto.com/7163375-74502COST SAVINGS: Carvana's business model has fewer expenses and no bloated fees compared to your local dealership. See how much we can save you at http://about.carvanaauto.comPREMIUM DETAIL: We go the extra mile so that your car is looking as good as new. There are a lot of specifics that we won’t list here (we wash, clean, buff, paint, polish, wax, seal), but trust us that when your car arrives, it’s going to look sweet.Vehicle Info for Stock# 2000977114Trim: LT Pickup 4D 6 1/2 ft pickupMileage: 71k milesExterior Color: BlueInterior Color: BlackEngine: Vortec 5.3L Flex Fuel V8 315hp 335ft. lbs.Drive: Two Wheel DriveTransmission: VIN: 1GCSCSE06AZ123805Dealer Disclosure: Price excludes tax, title, and registration (which we handle for you).Disclaimer: You agree that by providing your phone number, Carvana, or Carvana’s authorized representatives*, may call and/or send text messages (including by using equipment to automatically dial telephone numbers) about your interest in a purchase, for marketing/sales purposes, or for any other servicing or informational purpose related to your account. You do not have to consent to receiving calls or texts to purchase from Carvana. While every reasonable effort is made to ensure the accuracy of the information for this Chevrolet Silverado 1500 Extended Cab, we are not responsible for any errors or omissions contained in this ad. Please verif ...
# |7316814989|https://auburn.craigslist.org/ctd/d/auburn-university-2020-chevy-chevrolet/7316814989.html|auburn|https://auburn.craigslist.org|39590|2020|chevrolet   |silverado 1500 crew     |good     |8 cylinders|gas |19160   |clean       |other       |3GCPWCED5LG130317|NULL |NULL     |pickup|red        |https://images.craigslist.org/01212_jjirIWa0y02z_0gw0co_600x450.jpg|Carvana is the safer way to buy a car During these uncertain times, Carvana is dedicated to ensuring safety for all of our customers. In addition to our 100% online shopping and selling experience that allows all customers to buy and trade their cars without ever leaving the safety of their house, we’re providing touchless delivery that make all aspects of our process even safer. Now, you can get the car you want, and trade in your old one, while avoiding person-to-person contact with our friendly advocates. There are some things that can’t be put off. And if buying a car is one of them, know that we’re doing everything we can to keep you keep moving while continuing to put your health safety, and happiness first. Vehicle Stock# 2000948059📱 Want to instantly check this car’s availability? Call us at  334-758-9176Just text that stock number to 855-976-4304 or head to http://www.carvanaauto.com/6965441-74502 and plug it into the search bar!Get PRE-QUALIFIED for your auto loan in 2 minutes - no hit to your credit:http://finance.carvanaauto.com/6965441-74502Looking for more cars like this one? We have 144 Chevrolet Silverado 1500 Crew Cab in stock for as low as $20990!Why buy with Carvana? We have one standard: the highest. Take a look at just some of the qualifications all of our cars must meet before we list them.150-POINT INSPECTION: We put each vehicle through a 150-point inspection so that you can be 100% confident in its quality and safety. See everything that goes into our inspections at:http://www.carvanaauto.com/6965441-74502NO REPORTED ACCIDENTS: We do not sell cars that have been in a reported accident or have a frame or structural damage.7 DAY TEST OWN MONEY BACK GUARANTEE: Every Carvana car comes with a 7-day money-back guarantee. Why? It takes more than 15-minutes to make a decision on your next car. Learn more about test owning at http://about.carvanaauto.comFLEXIBLE FINANCING, TRADE INS WELCOME: We’re all about real-time financing without the middle man. Need financing? Pick a combination of down and monthly payments that work for you. Have a trade-in? We’ll give you a value in 2 minutes. Check out everything about our financing at:http://finance.carvanaauto.com/6965441-74502COST SAVINGS: Carvana's business model has fewer expenses and no bloated fees compared to your local dealership. See how much we can save you at http://about.carvanaauto.comPREMIUM DETAIL: We go the extra mile so that your car is looking as good as new. There are a lot of specifics that we won’t list here (we wash, clean, buff, paint, polish, wax, seal), but trust us that when your car arrives, it’s going to look sweet.Vehicle Info for Stock# 2000948059Trim: LT Pickup 4D 5 3/4 ft pickupMileage: 19k milesExterior Color: RedInterior Color: BLACKEngine: EcoTec3 5.3L V8 355hp 383ft. lbs.Drive: Two Wheel DriveTransmission: VIN: 3GCPWCED5LG130317Dealer Disclosure: Price excludes tax, title, and registration (which we handle for you).Disclaimer: You agree that by providing your phone number, Carvana, or Carvana’s authorized representatives*, may call and/or send text messages (including by using equipment to automatically dial telephone numbers) about your interest in a purchase, for marketing/sales purposes, or for any other servicing or informational purpose related to your account. You do not have to consent to receiving calls or texts to purchase from Carvana. While every reasonable effort is made to ensure the accuracy of the information for this Chevrolet Silverado 1500 Crew Cab, we are not responsible for any errors or omissions contained in this ad. Please verify any information ...
# |7316743432|https://auburn.craigslist.org/ctd/d/auburn-university-2017-toyota-tundra/7316743432.html  |auburn|https://auburn.craigslist.org|30990|2017|toyota      |tundra double cab sr    |good     |8 cylinders|gas |41124   |clean       |other       |5TFRM5F17HX120972|NULL |NULL     |pickup|red        |https://images.craigslist.org/00x0x_1y9kIOzGCFaz_0gw0co_600x450.jpg|Carvana is the safer way to buy a car During these uncertain times, Carvana is dedicated to ensuring safety for all of our customers. In addition to our 100% online shopping and selling experience that allows all customers to buy and trade their cars without ever leaving the safety of their house, we’re providing touchless delivery that make all aspects of our process even safer. Now, you can get the car you want, and trade in your old one, while avoiding person-to-person contact with our friendly advocates. There are some things that can’t be put off. And if buying a car is one of them, know that we’re doing everything we can to keep you keep moving while continuing to put your health safety, and happiness first. Vehicle Stock# 2000905180📱 Want to instantly check this car’s availability? Call us at  334-758-9176Just text that stock number to 855-976-4304 or head to http://www.carvanaauto.com/6964121-74502 and plug it into the search bar!Get PRE-QUALIFIED for your auto loan in 2 minutes - no hit to your credit:http://finance.carvanaauto.com/6964121-74502Looking for more cars like this one? We have 24 Toyota Tundra Double Cab in stock for as low as $23990!Why buy with Carvana? We have one standard: the highest. Take a look at just some of the qualifications all of our cars must meet before we list them.150-POINT INSPECTION: We put each vehicle through a 150-point inspection so that you can be 100% confident in its quality and safety. See everything that goes into our inspections at:http://www.carvanaauto.com/6964121-74502NO REPORTED ACCIDENTS: We do not sell cars that have been in a reported accident or have a frame or structural damage.7 DAY TEST OWN MONEY BACK GUARANTEE: Every Carvana car comes with a 7-day money-back guarantee. Why? It takes more than 15-minutes to make a decision on your next car. Learn more about test owning at http://about.carvanaauto.comFLEXIBLE FINANCING, TRADE INS WELCOME: We’re all about real-time financing without the middle man. Need financing? Pick a combination of down and monthly payments that work for you. Have a trade-in? We’ll give you a value in 2 minutes. Check out everything about our financing at:http://finance.carvanaauto.com/6964121-74502COST SAVINGS: Carvana's business model has fewer expenses and no bloated fees compared to your local dealership. See how much we can save you at http://about.carvanaauto.comPREMIUM DETAIL: We go the extra mile so that your car is looking as good as new. There are a lot of specifics that we won’t list here (we wash, clean, buff, paint, polish, wax, seal), but trust us that when your car arrives, it’s going to look sweet.Vehicle Info for Stock# 2000905180Trim: SR Pickup 4D 6 1/2 ft pickupMileage: 41k milesExterior Color: RedInterior Color: GRAYEngine: 4.6L V8 310hp 327ft. lbs.Drive: Two Wheel DriveTransmission: VIN: 5TFRM5F17HX120972Dealer Disclosure: Price excludes tax, title, and registration (which we handle for you).Disclaimer: You agree that by providing your phone number, Carvana, or Carvana’s authorized representatives*, may call and/or send text messages (including by using equipment to automatically dial telephone numbers) about your interest in a purchase, for marketing/sales purposes, or for any other servicing or informational purpose related to your account. You do not have to consent to receiving calls or texts to purchase from Carvana. While every reasonable effort is made to ensure the accuracy of the information for this Toyota Tundra Double Cab, we are not responsible for any errors or omissions contained in this ad. Please verify any information in question with Carvana at ...
# |7316356412|https://auburn.craigslist.org/cto/d/auburn-university-2013-150/7316356412.html            |auburn|https://auburn.craigslist.org|15000|2013|ford        |f-150 xlt               |excellent|6 cylinders|gas |128000  |clean       |automatic   |NULL             |rwd  |full-size|truck |black      |https://images.craigslist.org/00404_l4loxHvdQefz_0CI0t2_600x450.jpg|2013 F-150 XLT V6 4 Door. Good condition. Leveling kit. New Tires.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# +----------+------------------------------------------------------------------------------------------+------+-----------------------------+-----+----+------------+------------------------+---------+-----------+----+--------+------------+------------+-----------------+-----+---------+------+-----------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows

# %%
from pyspark.sql.functions import min, max

# %%
df.agg(min(col('price')).alias('min_price'), max(col('price')).alias('max_price')).show()
# Out:
# +---------+---------+
# |min_price|max_price|
# +---------+---------+
# |         |       wa|
# +---------+---------+

# %%
spark.stop()
